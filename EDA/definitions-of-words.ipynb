# %%
from googlesearch import search
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from bs4 import BeautifulSoup
import urllib
import webbrowser
import requests
import selenium

# %%
df = pd.read_csv('../nytwit_v1.tsv', sep='\t')
df.head(10)
# Out:
#                        Time           Word     Category   \
# 0  Tue Nov 07 19:12:11 2017        ujigami      filtered
# 1  Tue Nov 07 19:12:15 2017       ganbarro      filtered
# 2  Tue Nov 07 19:12:25 2017       yamahoko      filtered
# 3  Wed Nov 08 10:01:04 2017        rememed         affix
# 4  Wed Nov 08 11:01:14 2017      andpinyon      filtered
# 5  Wed Nov 08 11:01:42 2017  underdramatic         affix
# 6  Wed Nov 08 11:02:00 2017  hyperhysteria         affix
# 7  Wed Nov 08 13:01:19 2017      verbolect      filtered
# 8  Wed Nov 08 23:01:13 2017     fluffypoos         blend
# 9  Wed Nov 08 23:01:15 2017  shaggydoodles  compound new
#
#                                                  URL
# 0  https://www.nytimes.com/2017/11/07/travel/shri...
# 1  https://www.nytimes.com/2017/11/07/travel/shri...
# 2  https://www.nytimes.com/2017/11/07/travel/shri...
# 3  https://www.nytimes.com/2017/11/08/opinion/ang...
# 4  https://www.nytimes.com/2017/11/08/sports/nava...
# 5  https://www.nytimes.com/2017/11/08/books/revie...
# 6  https://www.nytimes.com/2017/11/08/books/revie...
# 7  https://www.nytimes.com/2017/11/08/arts/design...
# 8  https://www.nytimes.com/2017/11/08/nyregion/wh...
# 9  https://www.nytimes.com/2017/11/08/nyregion/wh...

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#                           Time           Word    Category_  \
# 0     Tue Nov 07 19:12:11 2017        ujigami     filtered
# 1     Tue Nov 07 19:12:15 2017       ganbarro     filtered
# 2     Tue Nov 07 19:12:25 2017       yamahoko     filtered
# 3     Wed Nov 08 10:01:04 2017        rememed        affix
# 4     Wed Nov 08 11:01:14 2017      andpinyon     filtered
# ...                        ...            ...          ...
# 2582  Thu Mar 28 13:56:25 2019        deadass        affix
# 2583  Thu Mar 28 13:56:27 2019       faaamous  lengthening
# 2584  Thu Mar 28 18:56:34 2019  salpingectomy       domain
# 2585  Thu Mar 28 19:56:14 2019    strrrrrrong  lengthening
# 2586  Thu Mar 28 19:56:23 2019        maminha     filtered
#
#                                                     URL
# 0     https://www.nytimes.com/2017/11/07/travel/shri...
# 1     https://www.nytimes.com/2017/11/07/travel/shri...
# 2     https://www.nytimes.com/2017/11/07/travel/shri...
# 3     https://www.nytimes.com/2017/11/08/opinion/ang...
# 4     https://www.nytimes.com/2017/11/08/sports/nava...
# ...                                                 ...
# 2582  http://www.nytimes.com/2019/03/28/arts/music/b...
# 2583  http://www.nytimes.com/2019/03/28/arts/music/b...
# 2584  http://www.nytimes.com/2019/03/28/parenting/wh...
# 2585  http://www.nytimes.com/2019/03/28/books/review...
# 2586  https://www.nytimes.com/2019/03/28/dining/pala...
#
# [2587 rows x 4 columns]

# %%
word_df = df['Word']
word_df.head(10)
# Out:
# 0          ujigami
# 1         ganbarro
# 2         yamahoko
# 3          rememed
# 4        andpinyon
# 5    underdramatic
# 6    hyperhysteria
# 7        verbolect
# 8       fluffypoos
# 9    shaggydoodles
# Name: Word, dtype: object

# %%
from selenium import webdriver

word_definitions = []
for word in word_df.values[:10]:
    url = 'https://google.com/search?q={}'.format(word) + "+meaning"
    response = requests.get(url)
    bsoup = BeautifulSoup(response.text, 'html.parser')
    driver = webdriver.Chrome('../chromedriver')
#     definition = bsoup.find('span',{'class':'e24Kjd'})
#     print(definition)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../chromedriver': '../chromedriver'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-10-382bebc9aa21> in <module>
#       6     response = requests.get(url)
#       7     bsoup = BeautifulSoup(response.text, 'html.parser')
# ----> 8     driver = webdriver.Chrome('../chromedriver')
#       9 #     definition = bsoup.find('span',{'class':'e24Kjd'})
#      10 #     print(definition)
#
# /usr/local/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# /usr/local/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home
